# %%
# %sql
GRANT USE SCHEMA ON SCHEMA azureadb1.saleslt TO `hellen.yingl@gmail.com`;
grant select on table azureadb1.saleslt.address TO `hellen.yingl@gmail.com`;

# %%
# %fs
mounts()

# %%
from delta.tables import DeltaTable

# If the table is registered in a metastore
deltaTable = DeltaTable.forName(spark, "saleslt.address")
details = deltaTable.detail().collect()
print(details[0].location)

# %%
# %sql
select * from snapshots.address_snapshot where AddressID in(9,11)
